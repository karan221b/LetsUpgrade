# %% [markdown]
# # Question 1 Sort it in ascending order but all zeros should be at right hand side.

# %%
list1=[0,1,2,10,4,1,0,56,2,0,1,3,0,56,0,4]

# %%
list1.sort(reverse=1)

# %%
print(list1)
# Out:
# [56, 56, 10, 4, 4, 3, 2, 2, 1, 1, 1, 0, 0, 0, 0, 0]

# %% [markdown]
# # Question 2    Sort list

# %%
list2=[10,20,40,60,70,80]

# %%
list2.sort(reverse=1)

# %%
print(list2)
# Out:
# [80, 70, 60, 40, 20, 10]

# %%
list3 = [(10,4),(2,4),(6,7),(2,6)]

# %%
def fun1(x):
    return x[0]+x[1]
list3.sort(key=fun1)
print (list3)
# Out:
# [(2, 4), (2, 6), (6, 7), (10, 4)]
